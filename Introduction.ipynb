# %% [markdown]
# # Introduction
#
# Welcome to the HSF-India/ePIC workshop! In this workshop, we will be writing and running code within this environment. Each tutorial or section will have its own Jupyter notebook and instructions to get you started.

# %% [markdown]
# # Introduction to Jupyter Notebooks
#
# - Hit ctrl+enter to run a cell.
#     - Running the final shell in the notebook usually adds a new one immediately below too.
# - Each cell is a distinct bit of python code, or as in this cell, markdown text.
#     - You can change the type of the cell from the bar along the top
# - You can define variables and write code as you normally would.

# %%
print("\nYou can have multiple lines within a shell.\n")
FutureLine = "Remember that cells run sequentially, so you need to make sure things are defined before you use them!"
import math as maths # Because our imported mathematical functions are subject to a 10% tariff
import matplotlib
import numpy as np

# %%
print(FutureLine)
print("\nTry restarting your kernel and running this cell *before* the others.\n")

# %% [markdown]
# - It's usually a good idea to import the packages you want/need in one of your first few cells.
#     - Then, you won't need to worry about them later.
# - Select the Kernel tab to reset your kernel. You can, optionally, clear the output of your cells too.

# %%
#print("We can also add comments as we would in normal code too")

# %%
print("We can define and run for/while loops and if statements.\n")
for i in range (0,100):
    if(i!= 0 and i % 17 == 0):
        print(i)
print("\n\nAnd now a while loop.\n\n")
j=0
while j < 100:
    j+=4
    if(j!=0 and j % 20 == 0):
        print(j)

# %% [markdown]
# ## Quick Quiz
#
# - What is each of the loops above doing?

# %%
print("Of course, we can also make use of things we've imported too.\n")
print("\nYou remembered to run the import cell right?")
print(maths.cos((maths.pi)/2))

# %% [markdown]
# # Other Functionality
#
# We can also run python scripts/code directly (not within a notebook) in this environment. Additionally, we can also open a terminal window if we want to.
#
# We will need to use the terminal to run eic-shell a bit later.

# %% [markdown]
# # Downloading and Uploading Files
#
# - You can download notebooks you've been working on by right clicking them from the file browser and selecting download
#     - If the file or notebook is open, there's also an option at the top of the page.
# - You can uplaod files by selecting the "upload" button (two to the right of the big blue plus in the top left) and selecting the file from your local machine

# %% [markdown]
# # Remember to download your notebook files at the end of each session!
#
# ## If you don't, you risk losing your work!
#
# ## You can re-upload them next time and pick up where you left off :)

# %% [markdown]
# # Getting Code Repositories
#
# - You can clone git-repositories easily by opening a terminal window from the launcher
# - Then just type -
#     - Git clone **YOUR_GIT_REPO_URL**

# %% [markdown]
# # Commonly Imported Packages
#
# We will be making use of the following packages extensively
#
# - xrootd
# - uproot
# - fsspec-xrootd
# - Particle
# - numpy
# - matplotlib
#
# You might want to just copy paste these as in import in your first cell for each notebook. E.g.
#
# - import xrtood
